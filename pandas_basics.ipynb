# %%
import pandas as pd

# %% [markdown]
# Install this support library:
# - openpyxl: `pip install openpyxl`

# %%
df=pd.read_excel("datasets/book1.xlsx", 
              header=None, 
              names=['#','col1','col2','col3','col4'],
              index_col=0)

# %%
df # datsframe
# Out:
#    col1  col2  col3  col4
# #
# 1    23   334    98   -10
# 2    56   341    56    54
# 3    56   342    12   -40
# 4    34   234   122   -30
# 5    12   563    45     5

# %%
df['col1'] # series

# %%
df['col1','col3']
# Out:
# #
# 1    23
# 2    56
# 3    56
# 4    34
# 5    12
# Name: col1, dtype: int64

# %%
df.iloc[0] #row 0
# Out:
# col1     23
# col2    334
# col3     98
# col4    -10
# Name: 1, dtype: int64

# %%
print(df['col1'].sum()) # sum of col1
print(df['col1'].mean()) # mean of col2
print(df['col1'].max()) # max of col3
# Out:
# 181
# 36.2
# 56

# %%
df.col1.plot(kind='bar')
# Out:
# <Axes: xlabel='#'>

# %%
df.col1.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='#'>

# %% [markdown]
# passing your manual data dictionary to pandas

# %%
data = {
    "country": ["india","brazil","california","america","argentina"],
    "population": [200.89,143.5,887,889,565],
    "gdp": [1.86,1.3,2.6,11.4,0.29],
    "area": [98767,78966,8668,6788,9657]
}

cdf = pd.DataFrame(data)
cdf
# Out:
#       country  population    gdp   area
# 0       india      200.89   1.86  98767
# 1      brazil      143.50   1.30  78966
# 2  california      887.00   2.60   8668
# 3     america      889.00  11.40   6788
# 4   argentina      565.00   0.29   9657

# %%
cdf.plot(kind='bar', x='country', y='population', figsize=(6,4))
# Out:
# <Axes: xlabel='country'>

# %%
cdf.plot(kind='bar', x='country', y='population',logy=True)
# Out:
# <Axes: xlabel='country'>

# %%
cdf.plot(kind='bar', x='country', y='population',logy=True,
         color='green',
         alpha='0.5',
         hatch='//',
         edgecolor='white')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 cdf.plot(kind='bar', x='country', y='population',logy=True,
#       2          color='green',
#       3          alpha='0.5',
#       4          hatch='//',
#       5          edgecolor='white')
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1948, in BarPlot._make_plot(self, fig)
#    1946 else:
#    1947     w = self.bar_width / K
# -> 1948     rect = self._plot(
#    1949         ax,
#    1950         self.ax_pos + (i + 0.5) * w,
#    1951         y,
#    1952         w,
#    1953         start=start,
#    1954         label=label,
#    1955         log=self.log,
#    1956         **kwds,
#    1957     )
#    1958 self._append_legend_handles_labels(rect, label)
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1878, in BarPlot._plot(cls, ax, x, y, w, start, log, **kwds)
#    1867 @classmethod
#    1868 def _plot(  # type: ignore[override]
#    1869     cls,
#    (...)
#    1876     **kwds,
#    1877 ):
# -> 1878     return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\matplotlib\axes\_axes.py:2591, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2582 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2583     r = mpatches.Rectangle(
#    2584         xy=(l, b), width=w, height=h,
#    2585         facecolor=c,
#    (...)
#    2589         hatch=htch,
#    2590         )
# -> 2591     r._internal_update(kwargs)
#    2592     r.get_path()._interpolation_steps = 100
#    2593     if orientation == 'vertical':
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\matplotlib\artist.py:1192, in Artist._update_props(self, props, errfmt)
#    1189             if not callable(func):
#    1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
# -> 1192             ret.append(func(v))
#    1193 if ret:
#    1194     self.pchanged()
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\matplotlib\patches.py:423, in Patch.set_alpha(self, alpha)
#     421 def set_alpha(self, alpha):
#     422     # docstring inherited
# --> 423     super().set_alpha(alpha)
#     424     self._set_facecolor(self._original_facecolor)
#     425     self._set_edgecolor(self._original_edgecolor)
#
# File c:\Users\ASUS\miniconda3\Lib\site-packages\matplotlib\artist.py:1008, in Artist.set_alpha(self, alpha)
#     999 """
#    1000 Set the alpha value used for blending - not supported on all backends.
#    1001
#    (...)
#    1005     *alpha* must be within the 0-1 range, inclusive.
#    1006 """
#    1007 if alpha is not None and not isinstance(alpha, Real):
# -> 1008     raise TypeError(
#    1009         f'alpha must be numeric or None, not {type(alpha)}')
#    1010 if alpha is not None and not (0 <= alpha <= 1):
#    1011     raise ValueError(f'alpha ({alpha}) is outside 0-1 range')
#
# TypeError: alpha must be numeric or None, not <class 'str'>

# %%
cdf.columns.tolist()
# Out:
# ['country', 'population', 'gdp', 'area']
